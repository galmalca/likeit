# %%
import numpy as np
import pandas as pd
import json

with open('data/40k_movies_data.json') as data_file:    
    movies_df = json.load(data_file)
print(movies_df[600])
# Out:
# {'title': 'Candyman: Farewell to the Flesh (1995)', 'movieId': 606, 'genres': ['Fantasy', ' Horror']}

# %%
def algo(comparableItem):
    list = []
    bestScore = 0
    for movie in movies_df:
        if movie['movieId'] != comparableItem['movieId']:
            matchScore = 0
            for j in range(len(comparableItem['genres'])):
                for i in range(len(movie['genres'])):
                    if comparableItem['genres'][j]==movie['genres'][i]:
                        matchScore+=1
                    if matchScore > bestScore:
                        bestMatch = movie
                        bestScore = matchScore
                    if matchScore > 1 and len(movie['genres']) <= len(comparableItem['genres'])+1:
                        list.append(movie)
#     list.append(bestMatch)
    list.reverse()
#     return bestMatch
    return list

# %%
algo(movies_df[600])
# Out:
# [{'genres': ['Fantasy', ' Horror'],
#   'movieId': 165023,
#   'title': 'Phantasm: Ravager (2016)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 163208,
#   'title': 'Gargoyles (1972)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 159405,
#   'title': 'Rampo Noir (2005)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 159405,
#   'title': 'Rampo Noir (2005)'},
#  {'genres': ['Fantasy', ' Horror', ' War'],
#   'movieId': 158639,
#   'title': 'The Living and the Dead (2007)'},
#  {'genres': ['Fantasy', ' Horror', ' War'],
#   'movieId': 158639,
#   'title': 'The Living and the Dead (2007)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 156700,
#   'title': 'Monsterwolf (2010)'},
#  {'genres': ['Fantasy', ' Horror', ' Romance'],
#   'movieId': 155650,
#   'title': 'Little Dead Rotting Hood (2016)'},
#  {'genres': ['Fantasy', ' Horror', ' Romance'],
#   'movieId': 155650,
#   'title': 'Little Dead Rotting Hood (2016)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 155137,
#   'title': 'Arundhati (2009)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 155137,
#   'title': 'Arundhati (2009)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 154800,
#   'title': 'Successive Slidings of Pleasure (1974)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 152499,
#   'title': 'Hisss (2010)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 152499,
#   'title': 'Hisss (2010)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 152493,
#   'title': 'Scrawl (2015)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 151921,
#   'title': 'Narok (2005)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 151094,
#   'title': 'The Golem (1936)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 146052,
#   'title': 'A Nymphoid Barbarian in Dinosaur Hell (1990)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 146052,
#   'title': 'A Nymphoid Barbarian in Dinosaur Hell (1990)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 145078,
#   'title': 'Revelation (2002)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 145078,
#   'title': 'Revelation (2002)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 142266,
#   'title': 'Maléfique (2003)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 142266,
#   'title': 'Maléfique (2003)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 142154,
#   'title': 'Unlucky Charms (2013)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 139309,
#   'title': 'The Drownsman (2014)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 139309,
#   'title': 'The Drownsman (2014)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 136920,
#   'title': 'Horsehead (2014)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 136732,
#   'title': 'Axe Giant - The Wrath of Paul Bunyan (2013)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 136732,
#   'title': 'Axe Giant - The Wrath of Paul Bunyan (2013)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 136546,
#   'title': 'Puppet Master X: Axis Rising (2012)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 136546,
#   'title': 'Puppet Master X: Axis Rising (2012)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 136227,
#   'title': 'The Wicked (2013)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 136227,
#   'title': 'The Wicked (2013)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 134812,
#   'title': 'Der Samurai (2014)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 134812,
#   'title': 'Der Samurai (2014)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 134358,
#   'title': 'The Redwood Massacre (2014)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 130468,
#   'title': 'The Circle (2015)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 130468,
#   'title': 'The Circle (2015)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 130071,
#   'title': 'Nymph (2014)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 129030,
#   'title': 'The Coven (2015)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 128952,
#   'title': 'House IV (1992)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 128952,
#   'title': 'House IV (1992)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 125557,
#   'title': 'Devils Hand, The (La main du diable) (1943)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 122884,
#   'title': 'Insidious: Chapter 3 (2015)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 122884,
#   'title': 'Insidious: Chapter 3 (2015)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 122543,
#   'title': 'Warlock III: The End of Innocence (1999)'},
#  {'genres': ['Fantasy', ' Horror', ' Romance'],
#   'movieId': 121449,
#   'title': 'Wishmaster 4: The Prophecy Fulfilled (2002)'},
#  {'genres': ['Fantasy', ' Horror', ' Romance'],
#   'movieId': 121449,
#   'title': 'Wishmaster 4: The Prophecy Fulfilled (2002)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 121247,
#   'title': 'Wishmaster 3: Beyond the Gates of Hell (2001)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 119667,
#   'title': 'The Prophecy: Forsaken (2005)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 119667,
#   'title': 'The Prophecy: Forsaken (2005)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 116783,
#   'title': 'Queens Of Evil (1970)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 116417,
#   'title': 'The Snow Woman (1968)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 116165,
#   'title': 'Illusion Of Blood (1965)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 113261,
#   'title': 'Screamtime (1986)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 106700,
#   'title': 'Ferryman, The (2007)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 106700,
#   'title': 'Ferryman, The (2007)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 104091,
#   'title': "Devil's Nightmare, The (Plus longue nuit du diable, La) (1971)"},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 102682,
#   'title': 'Livid (Livide) (2011)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 102499,
#   'title': 'Flaying, The (El Bosque de los Sometidos) (2012)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 102499,
#   'title': 'Flaying, The (El Bosque de los Sometidos) (2012)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 98120,
#   'title': 'Wishmaster 2: Evil Never Dies (1999)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 95969,
#   'title': 'Vampire Journals (1997)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 93500,
#   'title': 'Kill by Inches (1999)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 93500,
#   'title': 'Kill by Inches (1999)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 90907,
#   'title': 'Eerie Tales (Unheimliche Geschichten) (1919)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 90907,
#   'title': 'Eerie Tales (Unheimliche Geschichten) (1919)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 90453,
#   'title': 'Mystics in Bali (Leák)(1981)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 90453,
#   'title': 'Mystics in Bali (Leák)(1981)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 90068,
#   'title': 'Zaat (1971)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 90068,
#   'title': 'Zaat (1971)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 88754,
#   'title': 'Shanks (1974)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 85788,
#   'title': 'Insidious (2010)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 85788,
#   'title': 'Insidious (2010)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 85412,
#   'title': 'Troll Hunter, The (Trolljegeren) (2010)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 84510,
#   'title': 'Belphecor: Curse of the Mummy (Belphégor - Le fantôme du Louvre) (2001)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 84510,
#   'title': 'Belphecor: Curse of the Mummy (Belphégor - Le fantôme du Louvre) (2001)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 81184,
#   'title': 'Short Film About John Bolton, A (2003)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 81184,
#   'title': 'Short Film About John Bolton, A (2003)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 78949,
#   'title': 'Out of Mind: The Stories of H.P. Lovecraft (1998)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 78059,
#   'title': 'Velvet Vampire, The (1971)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 77798,
#   'title': 'Nightmare on Elm Street, A (2010)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 77798,
#   'title': 'Nightmare on Elm Street, A (2010)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 76832,
#   'title': "Black Waters of Echo's Pond, The (2009)"},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 76832,
#   'title': "Black Waters of Echo's Pond, The (2009)"},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 70946,
#   'title': 'Troll 2 (1990)'},
#  {'genres': ['Fantasy', ' Horror', ' Musical'],
#   'movieId': 65868,
#   'title': 'Repo! The Genetic Opera (2008)'},
#  {'genres': ['Fantasy', ' Horror', ' Musical'],
#   'movieId': 65868,
#   'title': 'Repo! The Genetic Opera (2008)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 65518,
#   'title': 'Dungeonmaster, The (1985)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 65518,
#   'title': 'Dungeonmaster, The (1985)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 61398,
#   'title': 'Mother of Tears: The Third Mother (Terza madre, La) (2007)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 61398,
#   'title': 'Mother of Tears: The Third Mother (Terza madre, La) (2007)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 60463,
#   'title': 'Dark Floors (2008)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 54171,
#   'title': 'Re-cycle (Gwai wik) (2006)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 46627,
#   'title': "Rock 'n' Roll Nightmare (1987)"},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 45081,
#   'title': 'Silent Hill (2006)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 45081,
#   'title': 'Silent Hill (2006)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 43906,
#   'title': 'Tamara (2005)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 43906,
#   'title': 'Tamara (2005)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 40467,
#   'title': 'Gorgon, The (1964)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 40467,
#   'title': 'Gorgon, The (1964)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 34659,
#   'title': 'She Creature (Mermaid Chronicles Part 1: She Creature) (2001)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 34659,
#   'title': 'She Creature (Mermaid Chronicles Part 1: She Creature) (2001)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 31950,
#   'title': 'Curse of the Demon (Night of the Demon) (1957)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 31950,
#   'title': 'Curse of the Demon (Night of the Demon) (1957)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 27778,
#   'title': 'Ginger Snaps Back: The Beginning (2004)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 26973,
#   'title': 'Snow White: A Tale of Terror (1997)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 26643,
#   'title': 'Tales from the Gimli Hospital (1988)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 26026,
#   'title': 'Undead, The (1957)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 25793,
#   'title': 'Vampyr (1932)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 25737,
#   'title': 'Golem, The (Golem, wie er in die Welt kam, Der) (1920)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 7951,
#   'title': 'Nightbreed (1990)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 7561,
#   'title': 'Paperhouse (1988)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 7561,
#   'title': 'Paperhouse (1988)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 5895,
#   'title': 'Making Contact (a.k.a. Joey) (1985)'},
#  {'genres': ['Fantasy', ' Horror', ' Sci-Fi'],
#   'movieId': 5895,
#   'title': 'Making Contact (a.k.a. Joey) (1985)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 5797,
#   'title': 'Company of Wolves, The (1984)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 5695,
#   'title': 'To the Devil a Daughter (1976)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 5695,
#   'title': 'To the Devil a Daughter (1976)'},
#  {'genres': ['Fantasy', ' Horror'],
#   'movieId': 5128,
#   'title': 'Queen of the Damned (2002)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 4105,
#   'title': 'Evil Dead, The (1981)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 4105,
#   'title': 'Evil Dead, The (1981)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 3772,
#   'title': 'Hatchet for the Honeymoon (Rosso segno della follia, Il) (1970)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 3772,
#   'title': 'Hatchet for the Honeymoon (Rosso segno della follia, Il) (1970)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 3216,
#   'title': 'Vampyros Lesbos (Vampiras, Las) (1971)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 3216,
#   'title': 'Vampyros Lesbos (Vampiras, Las) (1971)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 2327,
#   'title': 'Tales from the Darkside: The Movie (1990)'},
#  {'genres': ['Fantasy', ' Horror', ' Thriller'],
#   'movieId': 2327,
#   'title': 'Tales from the Darkside: The Movie (1990)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 188,
#   'title': 'Prophecy, The (1995)'},
#  {'genres': ['Fantasy', ' Horror', ' Mystery'],
#   'movieId': 188,
#   'title': 'Prophecy, The (1995)'}]

# %%
# #convert file
# with open('data/40k_movies_data.json') as data_file:    
#     data = json.load(data_file)

# for item in data:
#     str = item['genres']
#     wards = str.split(',')
#     item['genres'] = wards

# with open('data/40k_movies_data.json', 'w') as outfile:
#     json.dump(data, outfile)
